# %%
import cv2
import os
import sys

# %%
vid_path = "/project/004_data/vids/deictic_right_hand_v5.avi"
out_path = "/project/004_data/imgs"
video = cv2.VideoCapture(vid_path)

# %%
vid_name = vid_path.split('/')[-1].split('.')[0]
print(vid_name)
# Out:
# deictic_right_hand_v4

# %%
out_full_path = os.path.join(out_path, vid_name)
print(out_full_path)

try:
    os.mkdir(out_path)
    os.mkdir(out_full_path)
except OSError:
    print("directory exists")
# Out:
# /project/004_data/imgs/deictic_right_hand_v4
# directory exists

# %%
fcount = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
print(fcount)
# Out:
# 188

# %%
file_list = []
for i in range(0,fcount):
    ret, frame = video.read()
    assert ret
    resized_frame = cv2.resize(frame, (480, 640))
    cv2.imwrite('{}/img_{:05d}.jpg'.format(out_full_path, i), resized_frame)
    #access_path = '{}/{:05d}.jpg {} 0'.format(out_full_path, i, fcount)
access_path = '{} {} {}'.format(out_full_path, fcount, 0)
file_list.append(access_path)
print('{} done'.format(vid_name))
video.release()
#sys.stdout.flush()
print(file_list)
# Out:
# deictic_right_hand_v4 done
# ['/project/004_data/imgs/deictic_right_hand_v4 188 0']

# %%
print(file_list)
# Out:
# ['/project/004_data/imgs/deictic_right_hand_v4 188 0']
